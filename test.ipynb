# %%
import os
#set workdir
os.chdir("/content/drive/MyDrive/RiverSemanticSegmentation/")

# %%
arr = [1,2,3,4,5]
for i, item in enumerate(arr):
  arr[i] = 6
print(arr)
# Out:
# [6, 6, 6, 6, 6]

# %%
import torchvision.models as models
pretrained = models.vgg16(pretrained=True)
print(pretrained.state_dict().keys())
from models.vgg_unet_ks import VggUnetKs
model = VggUnetKs()
print(model.state_dict().keys())
# Out:
# odict_keys(['features.0.weight', 'features.0.bias', 'features.2.weight', 'features.2.bias', 'features.5.weight', 'features.5.bias', 'features.7.weight', 'features.7.bias', 'features.10.weight', 'features.10.bias', 'features.12.weight', 'features.12.bias', 'features.14.weight', 'features.14.bias', 'features.17.weight', 'features.17.bias', 'features.19.weight', 'features.19.bias', 'features.21.weight', 'features.21.bias', 'features.24.weight', 'features.24.bias', 'features.26.weight', 'features.26.bias', 'features.28.weight', 'features.28.bias', 'classifier.0.weight', 'classifier.0.bias', 'classifier.3.weight', 'classifier.3.bias', 'classifier.6.weight', 'classifier.6.bias'])
# odict_keys(['conv_down1.0.weight', 'conv_down1.0.bias', 'conv_down1.2.weight', 'conv_down1.2.bias', 'conv_down2.0.weight', 'conv_down2.0.bias', 'conv_down2.2.weight', 'conv_down2.2.bias', 'conv_down3.0.weight', 'conv_down3.0.bias', 'conv_down3.2.weight', 'conv_down3.2.bias', 'conv_down3.4.weight', 'conv_down3.4.bias', 'conv_down4.0.weight', 'conv_down4.0.bias', 'conv_down4.2.weight', 'conv_down4.2.bias', 'conv_down4.4.weight', 'conv_down4.4.bias', 'conv_bottom.weight', 'conv_bottom.bias', 'conv_up4.0.weight', 'conv_up4.0.bias', 'conv_up4.2.weight', 'conv_up4.2.bias', 'conv_up4.2.running_mean', 'conv_up4.2.running_var', 'conv_up4.2.num_batches_tracked', 'conv_up3.0.weight', 'conv_up3.0.bias', 'conv_up3.2.weight', 'conv_up3.2.bias', 'conv_up3.2.running_mean', 'conv_up3.2.running_var', 'conv_up3.2.num_batches_tracked', 'conv_up2.0.weight', 'conv_up2.0.bias', 'conv_up2.2.weight', 'conv_up2.2.bias', 'conv_up2.2.running_mean', 'conv_up2.2.running_var', 'conv_up2.2.num_batches_tracked', 'conv_up1.0.weight', 'conv_up1.0.bias', 'conv_up1.2.weight', 'conv_up1.2.bias', 'conv_up1.2.running_mean', 'conv_up1.2.running_var', 'conv_up1.2.num_batches_tracked', 'conv_last.weight', 'conv_last.bias'])
