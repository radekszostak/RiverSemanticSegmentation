# %%
import os

# %%
os.chdir("/content/drive/MyDrive/SemanticSegmentationV2/pytorch/")
dataset_dir = os.path.normpath("/content/drive/MyDrive/SemanticSegmentationV2/dataset/")
print(dataset_dir)
print(os.listdir(dataset_dir))
# Out:
# /content/drive/MyDrive/SemanticSegmentationV2/dataset
# ['log.txt', 'Y_train', 'X_test', 'X_train', 'Y_test']
